# %%
import pandas as pd    
import numpy as np
import sqlite3 as sql

class Size:
    def __init__(self, db):
        self.conn = sql.connect('sqlite-jcodeodor/database/'+db)

    def dist(self): 
        return pd.read_sql('select name,type,value from detect_dcoh',self.conn)

    def get_LOCs(self):
        rawsql = "SELECT mb.name, value as LOC FROM Measures ms join Measurables mb on mb.id = ms.measurable "
        rawsql += "where key = 'LOC'  and  mb.name in "
        rawsql += "('RealProject','EditorController','TransTipsMarker','GlossaryTextArea','Main',"
        rawsql += "'ScriptingWindow','ProjectUICommands','CalcMatchStatistics','BrowseTaasCollectionsController','AlignPanelController','DictionariesTextArea','AlignFilePickerController','SegmentBuilder','SearchWindowController','EntryListPane','SegmentPropertiesTableView','PreferencesWindowController','ProjectProperties','TaaSPlugin',"
        rawsql += "'SegmentPropertiesArea','ProjectTMX','ProjectTMX.Loader','Core') order by name"                
        return pd.read_sql(rawsql,self.conn)

comp = Size('1-compiled.sqlite')
exp2 = Size('3-experiment2.sqlite')

comp.get_LOCs()
# Out:
#                                name     LOC
# 0         AlignFilePickerController   376.0
# 1              AlignPanelController  1981.0
# 2   BrowseTaasCollectionsController   310.0
# 3               CalcMatchStatistics   262.0
# 4                              Core   297.0
# 5              DictionariesTextArea   333.0
# 6                  EditorController  2037.0
# 7                     EntryListPane   604.0
# 8                  GlossaryTextArea   333.0
# 9                              Main   484.0
# 10      PreferencesWindowController   866.0
# 11                ProjectProperties   545.0
# 12                       ProjectTMX   347.0
# 13                ProjectTMX.Loader    76.0
# 14                ProjectUICommands   973.0
# 15                      RealProject  1779.0
# 16                  ScriptingWindow   931.0
# 17           SearchWindowController  1073.0
# 18                   SegmentBuilder   663.0
# 19            SegmentPropertiesArea   315.0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1696         try:
# -> 1697             cur.execute(*args, **kwargs)
#    1698             return cur
#
# OperationalError: near "key": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-3-ecbc4dbd3ec3> in <module>
# ----> 1 comp.get_LOCs()
#
# <ipython-input-2-47eaaf6557c5> in get_LOCs(self)
#      15         rawsql += "('RealProject','EditorController','TransTipsMarker','GlossaryTextArea','Main',"
# ...
